# %% [markdown]
# Este é um programa que visa agrupar palavras de uma lista com relação ao seu significado. Ou seja, palavras como "screen" e "display", ou "processor" e "cpu" deverão estar próximas umas das outras, apesar de terem a escrita bastante diferente.
#
# Para isso, será usada a técnica de embedding, que "traduz" strings para vetores n-dimensionais, de acordo com um treinamento prévio em textos. Porém, ao invés de treinar minha própria rede neural, decidi baixar uma base de dados com palavras já traduzidas em vetores por uma rede neural treinada anteriormente por terceiros. Acabei optando por esta escolha por não ter muita confiabilidade nas bases de treinamento que encontrei, e também porque, aparentemente, a diferença entre treinar sua própria rede neural para embeddings do zero não é tão melhor do que pegar um conjunto de vetores pré-treinados. (https://towardsdatascience.com/pre-trained-word-embeddings-or-embedding-layer-a-dilemma-8406959fd76c).
#
# Reconheço que poderia alcançar um resultado mais preciso caso fizesse meu próprio treino, mas precisaria de uma base de dados própria, como as reviews de onde as palavras da lista original foram tiradas.
#
# A base de dados utilizada foi baixada de https://nlp.stanford.edu/projects/glove/, e ela foi treinada com páginas da Wikipedia e Gigaword. Desta maneira, espero que os vetores consigam aproximar termos técnicos e termos coloquiais com a mesma facilidade. Créditos a Jeffrey Pennington, Richard Socher e Christopher D. Manning. 2014. GloVe: Global Vectors for Word Representation.

# %%
from numpy import array
from numpy import asarray
from numpy import zeros

dicio = dict()
file = open('glove.6B.300d.txt', encoding="utf8")
for i in file:
    aux = i.split()
    palavra = aux[0]
    vect = asarray(aux[1:], dtype='float32')
    dicio [palavra] = vect

file.close()

# %%
# Importando o arquivo .csv recebido
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
palavras = pd.read_csv('laptop_filtered_aspect_sample.csv', header=(0))


print(palavras.shape)
#Conferindo se a base foi corretamente exportada
# Out:
# (7335, 1)

# %%
#Alguns termos na pesquisa são compostos de duas palavras separadas. Achei melhor dividi-las na hora de configurar o algoritmo.
def quebraPalavras(data,header):
    auxHeader = [header]
    auxList = []
    for i in range(data.size):
        stringParaQuebrar = data.iloc[i][header]
        stringParaQuebrar = stringParaQuebrar.split()
        for i in range(len(stringParaQuebrar)):
            auxList.append(stringParaQuebrar[i])
    
    brokenData = pd.DataFrame(auxList) 
    #brokenData = brokenData.append(brokenData, auxList, ignore_index=True)    
    brokenData = brokenData.drop_duplicates()
    
    return brokenData

# %%
# Temos dois dataframes: o original (palavras) e um com termos compostos separados (palavrasSeparadas)

palavrasSeparadas = quebraPalavras(palavras,'aspect_name')

#verificando diferença entre os dois dataframes
print(palavrasSeparadas.shape)
# Out:
# (3493, 1)

# %%
def adicionaVec(data,header):
    auxListPalavras = []
    auxListVetores = []
    auxListOrphans = []
    for i in range(data.size):
        palavraPesquisada = data.iloc[i][header]
        
        if(palavraPesquisada in dicio):
            auxListPalavras.append(palavraPesquisada)
            auxVect = dicio[palavraPesquisada]
            auxListVetores.append(auxVect)
        else:
            auxListOrphans.append(palavraPesquisada)
            #print(palavraPesquisada, " Não foi encontrada.")

    listaPalavras = auxListPalavras
    listaVetores = np.array(auxListVetores)
    return listaPalavras,listaVetores,auxListOrphans

# %%
#formando a lista de palavras e a array de vetores. Por enquanto, palavras "órfãs", sem equivalência 
#na base baixada, serão deixadas de lado.
pal,vec,foo = adicionaVec(palavrasSeparadas,0)

print("Palavras encontradas:",len(pal))

print("Palavras não encontradas:",len(foo))
# Out:
# Palavras encontradas: 3285
# Palavras não encontradas: 208

# %% [markdown]
# Agora, captamos os dados e já temos equivalências para a grande maioria das palavras da lista. Ao inspecionar o .csv, é possível perceber que muitas delas estão em português. Isso complica bastante a análise, já que o dicionário é da língua inglesa, e simplesmente baixar um dicionário em português não daria a mesma equivalência de vetores. Uma possibilidade seria usar um dicionário para traduzir as palavras, mas isso adiciona ainda mais distorção. Por enquanto, deixarei as 208 palavras sem equivalência de lado.
#
# Agora, para procurar palavras com significados semelhantes, irei utilizar o algoritmo DBSCAN. Ele detecta aglomerados com base na densidade dos mesmos, e não dependem de quantidade de sementes. Isso será bastante útil, dado que não sabemos quantos "conjuntos sêmanticos" existem na base de dados.

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import DBSCAN

aglomerador = DBSCAN(eps = 0.5, min_samples=2, metric = 'cosine')
aglomerador.fit(vec)

tipos = aglomerador.labels_[range(len(pal))]

print("Quantidade de aglomerados encontrados:" , len(np.unique(tipos)-1))
print("Quantidade de palavras sem aglomerado:" , np.count_nonzero(tipos == -1))
# Out:
# Quantidade de aglomerados encontrados: 136
# Quantidade de palavras sem aglomerado: 868

# %% [markdown]
# O código acima foi criado para procurar por aglomerados relativamente pequenos, e ainda sim deixa várias palavras marcadas como "outliers". Vou analisar com quantidades diferentes de elementos mínimos para aglomerado.

# %%
def testaDBSCAN(vec):
    for i in range(10):
        aglomerador = DBSCAN(min_samples=i, metric = 'cosine')
        aglomerador.fit(vec)

        tipos = aglomerador.labels_[range(len(pal))]
        print("Clusters com um mínimo de ",i," elementos")
        print("Quantidade de aglomerados encontrados:" , len(np.unique(tipos)-1))
        print("Quantidade de palavras sem aglomerado:" , np.count_nonzero(tipos == -1))
        print("-"*20)
        
testaDBSCAN(vec)
# Out:
# Clusters com um mínimo de  0  elementos
# Quantidade de aglomerados encontrados: 1003
# Quantidade de palavras sem aglomerado: 0
# --------------------
# Clusters com um mínimo de  1  elementos
# Quantidade de aglomerados encontrados: 1003
# Quantidade de palavras sem aglomerado: 0
# --------------------
# Clusters com um mínimo de  2  elementos
# Quantidade de aglomerados encontrados: 136
# Quantidade de palavras sem aglomerado: 868
# --------------------
# Clusters com um mínimo de  3  elementos
# Quantidade de aglomerados encontrados: 36
# Quantidade de palavras sem aglomerado: 1068
# --------------------
# Clusters com um mínimo de  4  elementos
# Quantidade de aglomerados encontrados: 15
# Quantidade de palavras sem aglomerado: 1236
# --------------------
# Clusters com um mínimo de  5  elementos
# Quantidade de aglomerados encontrados: 14
# Quantidade de palavras sem aglomerado: 1378
# --------------------
# Clusters com um mínimo de  6  elementos
# Quantidade de aglomerados encontrados: 9
# Quantidade de palavras sem aglomerado: 1489
# --------------------
# Clusters com um mínimo de  7  elementos
# Quantidade de aglomerados encontrados: 9
# Quantidade de palavras sem aglomerado: 1600
# --------------------
# Clusters com um mínimo de  8  elementos
# Quantidade de aglomerados encontrados: 8
# Quantidade de palavras sem aglomerado: 1681
# --------------------
# Clusters com um mínimo de  9  elementos
# Quantidade de aglomerados encontrados: 10
# Quantidade de palavras sem aglomerado: 1795
# --------------------

# %% [markdown]
# O número de aglomerados cai bastante conforme o número mínimo aumenta, mas a principal queda é de 2 para 3. Além disso, o número de palavras sem aglomerado não aumenta tanto, o que me leva a crer que as palavras "outliers" são bastante anormais, e nao aparecem muitas vezes. Vou analisar melhor os elementos sem aglomerado quando o cluster tem mínimo de 2 elementos.

# %%
aglomerador = DBSCAN(min_samples=2, metric = 'cosine')
aglomerador.fit(vec)

tipos = aglomerador.labels_[range(len(pal))]

indiceOutlier = 0
for i in range(len(tipos)):
    if(tipos[i]==-1): 
        print(indiceOutlier)
        print(pal[indiceOutlier])
    indiceOutlier = indiceOutlier+1
# Out:
# 20
# chromebook
# 35
# promotion
# 42
# gaming
# 75
# keys
# 78
# ssd
# 80
# lightweight
# 99
# specs
# 102
# touchpad
# 107
# chrome
# 121
# charger
# 136
# pro
# 137
# entrega
# 151
# trackpad
# 164
# super
# 168
# hdd
# 169
# pen
# 174
# sd
# 188
# o
# 193
# bottom
# 201
# boot
# 234
# brightness
# 245
# friendly
# 265
# heavy
# 272
# tabs
# 295
# portability
# 308
# lid
# 315
# notes
# 324
# tela
# 333
# stylus
# 334
# startup
# 339
# bateria
# 341
# reset
# 360
# responsive
# 366
# dia
# 371
# junk
# 382
# webcam
# 383
# hp
# 384
# bloatware
# 388
# netflix
# 400
# breeze
# 403
# slim
# 412
# everyday
# 416
# series
# 434
# core
# 444
# logo
# 447
# middle
# 474
# docs
# 498
# jack
# 499
# optical
# 500
# buck
# 512
# fps
# 514
# penny
# 524
# board
# 529
# bells
# 533
# bonus
# 550
# bucks
# 555
# ultra
# 557
# valor
# 562
# micro
# 569
# sync
# 573
# curve
# 574
# default
# 581
# sim
# 593
# bang
# 597
# macbooks
# 602
# compra
# 603
# x1
# 606
# mais
# 620
# extreme
# 631
# schedule
# 637
# scratch
# 639
# yoga
# 640
# dual
# 645
# caps
# 649
# enjoyed
# 653
# retina
# 658
# steal
# 660
# multitasking
# 667
# som
# 668
# walmart
# 669
# mousepad
# 672
# flash
# 684
# geral
# 699
# notch
# 713
# min
# 714
# intuitive
# 724
# yr
# 731
# ecosystem
# 749
# smooth
# 753
# lightning
# 755
# summary
# 773
# chassis
# 781
# back-lit
# 782
# brainer
# 794
# info
# 795
# drain
# 798
# factor
# 806
# bundle
# 809
# glare
# 815
# snap
# 821
# pin
# 833
# pack
# 835
# sturdy
# 836
# garantia
# 838
# tag
# 841
# tb
# 845
# estado
# 857
# self
# 862
# casing
# 863
# regular
# 865
# excelente
# 867
# format
# 880
# trabalho
# 884
# shot
# 895
# versatile
# 898
# flex
# 900
# spec
# 901
# quad
# 903
# reboot
# 910
# tempo
# 912
# tab
# 923
# pics
# 925
# dongle
# 927
# softwares
# 929
# sensitivity
# 930
# general
# 932
# mobility
# 933
# grad
# 949
# gestures
# 955
# champ
# 962
# rw
# 3049
# fat
# 3052
# salvo
# 3053
# gon
# 3054
# clunker
# 3055
# oversight
# 3058
# clone
# 3060
# overnight
# 3061
# voucher
# 3064
# overclocking
# 3065
# flickered
# 3066
# chi
# 3067
# seams
# 3070
# fica
# 3071
# securely
# 3073
# sempre
# 3074
# sendo
# 3077
# 5x
# 3078
# sequence
# 3079
# serviço
# 3082
# kicks
# 3084
# shake
# 3087
# wipe
# 3096
# fingertip
# 3098
# camel
# 3101
# enemy
# 3110
# bumps
# 3111
# mines
# 3112
# newbie
# 3113
# introduction
# 3114
# interruption
# 3118
# branch
# 3121
# witch
# 3123
# número
# 3124
# integrates
# 3126
# bootable
# 3130
# spills
# 3131
# bom
# 3132
# square
# 3133
# formatting
# 3134
# stack
# 3136
# ops
# 3138
# fotos
# 3139
# wobbly
# 3143
# wow
# 3144
# strike
# 3147
# binge
# 3149
# optimization
# 3150
# misrepresentation
# 3153
# illumination
# 3154
# bench
# 3155
# idle
# 3157
# accomplished
# 3160
# tact
# 3163
# :
# 3164
# -
# 3165
# tbm
# 3166
# hyper
# 3167
# threading
# 3168
# techy
# 3171
# thou
# 3176
# baixo
# 3178
# shabby
# 3179
# top-notch
# 3184
# nicks
# 3193
# trim
# 3199
# twins
# 3203
# earphone
# 3204
# uhd
# 3206
# ultraportable
# 3207
# unbearably
# 3210
# non-apple
# 3211
# grading
# 3213
# adjustable
# 3214
# vale
# 3215
# appreciation
# 3217
# anterior
# 3218
# anomaly
# 3222
# estrelas
# 3229
# peeve
# 3231
# dentro
# 3234
# pinhole
# 3237
# whim
# 3239
# expedited
# 3241
# shallow
# 3246
# octane
# 3247
# popups
# 3250
# pos
# 3251
# ddr3
# 3253
# hungry
# 3254
# hds
# 3255
# occasional
# 3256
# gym
# 3257
# predator
# 3261
# gut
# 3263
# lows
# 3264
# guest
# 3268
# obsolescence
# 3269
# unhelpful
# 3274
# crafting
# 3275
# airflow
# 3280
# logic
# 3282
# coupon

# %% [markdown]
# Ao analisar os "outliers", se percebe que há algumas palavras em português perdidas no meio, e algumas outras que um humano consideraria semelhante. Porém, várias outras usam termos pouco convencionais ou gírias, como "wow" e "sleekness". Treinar uma máquina para reconhecer exemplos dentro de um texto provavelmente teria sido capaz de agrupar esses dados, uma vez que essas gírias viriam junto de um contexto.
#
# Irei refazer a análise com a lista original, sem separações, para verificar se existiam "outliers" com um contexto que foi perdido.

# %%
palNov,vecNov,fooNov = adicionaVec(palavras,'aspect_name')

print("Palavras encontradas:",len(palNov))

print("Palavras não encontradas:",len(fooNov))
# Out:
# Palavras encontradas: 2659
# Palavras não encontradas: 4676

# %%
aglomerador = DBSCAN(min_samples=2, metric = 'cosine')
aglomerador.fit(vecNov)

tiposNovos = aglomerador.labels_[range(len(palNov))]

print("Quantidade de aglomerados encontrados:" , len(np.unique(tiposNovos)-1))
print("Quantidade de palavras sem aglomerado:" , np.count_nonzero(tiposNovos == -1))
# Out:
# Quantidade de aglomerados encontrados: 128
# Quantidade de palavras sem aglomerado: 784

# %%
print("Taxa de outliers com palavras divididas:",np.count_nonzero(tipos == -1)/len(pal))
print("Taxa de outliers com palavras juntas (sem divisão):",np.count_nonzero(tiposNovos == -1)/len(palNov))
# Out:
# Taxa de outliers com palavras divididas: 0.26423135464231357
# Taxa de outliers com palavras juntas (sem divisão): 0.2948476871004137

# %% [markdown]
# Dividir as palavras aumentou a taxa de reconhecimento do algoritmo, mas creio que uma IA treinada com uma base de comentários seria capaz de identificar melhor esses conjuntos.
#
# Os códigos abaixo podem ser utilizados para buscar por palavras e conjuntos.

# %%
def conteudoDoCluster(numCluster):
    conteudos = []
    for i in range(len(pal)):
        if(tipos[i]==numCluster): 
            conteudos.append(pal[i])
    print("O aglomerado possui as palavras:",conteudos)
    print(len(conteudos))


def estaEmCluster(palavraPraChecar):
    for i in range(len(pal)):
        if(pal[i]==palavraPraChecar): 
            print("A palavra", pal[i], "está na posição", i, "da lista, e no cluster", tipos[i])
            if(tipos[i]!=-1): 
                conteudoDoCluster(tipos[i])
            else:
                print("A palavra foi considerada como outlier.")
            break
    print("Palavra não encontrada.")

# %%
estaEmCluster("life")
# Out:
# A palavra life está na posição 11 da lista, e no cluster 0
# O aglomerado possui as palavras: ['laptop', 'use', 'computer', 'screen', 'price', 'keyboard', 'work', 'product', 'fast', 'time', 'life', 'notebook', 'easy', 'purchase', 'works', 'performance', 'machine', 'looking', 'very', 'good', 'quality', 'money', 'light', 'windows', 'little', 'speed', 'size', 'run', 'problem', 'apps', 'games', 'internet', 'school', 'display', 'issues', 'review', 'was', 'hours', 'set', 'problems', 'tablet', 'os', 'device', 'design', 'memory', 'day', 'ram', 'daughter', 'happy', 'software', 'power', 'runs', 'hard', 'drive', 'programs', 'update', 'laptops', 'features', 'return', 'issue', 'system', 'college', 'needs', 'storage', 'look', 'great', 'pc', 'processor', 'model', 'sound', 'weight', 'box', 'usb', 'start', 'charge', 'fan', 'touchscreen', 'bit', 'upgrade', 'son', 'home', 'cost', 'long', 'slow', 'products', 'videos', 'mouse', 'hardware', 'value', 'type', 'graphics', 'gb', 'unit', 'delivery', 'computers', 'ports', 'install', 'download', 'small', 'support', 'case', 'email', 'wife', 'store', 'updates', 'web', 'phone', 'stars', 'pretty', 'office', 'pleased', 'video', 'installed', 'setup', 'reviews', 'air', 'brand', 'new', 'charging', 'color', 'space', 'sale', 'version', 'feature', 'port', 'built', 'watch', 'minutes', 'cpu', 'desktop', 'carry', 'movies', 'access', 'nice', 'connect', 'seconds', 'experience', 'quick', 'item', 'build', 'complaints', 'load', 'music', 'service', 'wifi', 'operating', 'settings', 'ease', 'backlit', 'card', 'game', 'plug', 'shipping', 'top', 'applications', 'customer', 'resolution', 'beautiful', 'kids', 'app', 'files', 'thin', 'option', 'deal', 'site', 'user', 'business', 'hd', 'excellent', 'satisfied', 'program', 'side', 'i7', 'reading', 'surface', 'fit', 'cheap', 'company', 'documents', 'student', 'mode', 'powerful', 'drivers', 'typing', 'setting', 'linux', 'black', 'beat', 'key', 'slot', 'market', 'line', 'repair', 'love', 'simple', 'fans', 'homework', 'available', 'plenty', 'care', 'hour', 'functions', 'photos', 'camera', 'browser', 'browsing', 'click', 'audio', 'noise', 'job', 'travel', 'students', 'compact', 'order', 'pictures', 'fits', 'functionality', 'colors', 'function', 'call', 'perfect', 'point', 'emails', 'trouble', 'button', 'lap', 'adapter', 'benefit', 'bright', 'piece', 'big', 'picture', 'as', 'lag', 'website', 'book', 'macbook', 'so', 'ability', 'seller', 'place', 'tech', 'really', 'person', 'google', 'feel', 'tasks', 'cool', 'waste', 'clean', 'buy', 'disappointed', 'devices', 'friends', 'track', 'opening', 'family', 'husband', 'loud', 'star', 'class', 'hot', 'help', 'hands', 'account', 'data', 'bios', 'i5', 'old', 'process', 'room', 'package', 'headphones', 'looks', 'outside', 'cloud', 'charges', 'bluetooth', 'large', 'hdmi', 'tv', 'heat', 'refund', 'plastic', 'finish', 'processing', 'house', 'driver', 'friend', 'printer', 'addition', 'budget', 'editing', 'dell', 'other', 'backpack', 'options', 'inch', 'configuration', 'running', 'break', 'material', 'choice', 'comfortable', 'usage', 'night', 'description', 'equipment', 'difficult', 'users', 'gamer', 'volume', 'range', 'machines', 'dvd', 'quiet', 'deadline', 'personal', 'efficient', 'test', 'technology', 'more', 'expensive', 'durable', 'priced', 'connection', 'impressed', 'cable', 'word', 'buttons', 'motherboard', 'too', 'dollars', 'mail', 'response', 'fault', 'hand', 'highly', 'recommended', 'models', 'liked', 'high', 'full', 'tablets', 'desk', 'search', 'password', 'print', 'stand', 'wireless', 'information', 'sharp', 'complete', 'charged', 'well', 'bag', 'strong', 'loading', 'reader', 'front', 'fingers', 'cursor', 'photo', 'limited', 'image', 'text', 'designed', 'instructions', 'view', 'prices', 'useful', 'writing', 'screens', 'plus', 'condition', 'designer', 'apple', 'convenient', 'complaint', 'packaging', 'finger', 'security', 'contact', 'level', 'page', 'lenovo', 'bill', 'short', 'classes', 'pages', 'not', 'net', 'mom', 'pain', 'damage', 'solid', 'state', 'android', 'minute', 'sleep', 'road', 'manufacturer', 'p ...
# 2063
# Palavra não encontrada.

# %%
for i in range(130):
    conteudoDoCluster(i+1)
# Out:
# O aglomerado possui as palavras: ['battery', 'batteries', 'recharge', 'recharges']
# 4
# O aglomerado possui as palavras: ['com', 'dot']
# 2
# O aglomerado possui as palavras: ['touch', 'touches']
# 2
# O aglomerado possui as palavras: ['speakers', 'speaker']
# 2
# O aglomerado possui as palavras: ['warranty', 'warranties']
# 2
# O aglomerado possui as palavras: ['gift', 'gifts']
# 2
# O aglomerado possui as palavras: ['pros', 'cons']
# 2
# O aglomerado possui as palavras: ['handle', 'handling', 'handles']
# 3
# O aglomerado possui as palavras: ['replacement', 'replacements', 'replaced', 'replacing']
# 4
# O aglomerado possui as palavras: ['monitor', 'monitors']
# 2
# O aglomerado possui as palavras: ['pad', 'pads']
# 2
# O aglomerado possui as palavras: ['antes', 'todas', 'todos', 'por', 'que', 'con', 'si', 'de', 'para', 'recursos', 'y', 'problemas', 'parte', 'problema', 'ano', 'apenas', 'anos', 'como', 'mas', 'principio']
# 20
# O aglomerado possui as palavras: ['cover', 'covers']
# 2
# O aglomerado possui as palavras: ['scratches', 'blemishes', 'scrapes']
# 3
# O aglomerado possui as palavras: ['boots', 'wear', 'suits']
# 3
# O aglomerado possui as palavras: ['c', 'g', 'k', 'l', 'h', 'w']
# 6
# O aglomerado possui as palavras: ['bar', 'bars']
# 2
# O aglomerado possui as palavras: ['hinge', 'hinges']
# 2
# O aglomerado possui as palavras: ['é', 'não', 'só']
# 3
# O aglomerado possui as palavras: ['lock', 'locks']
# 2
# O aglomerado possui as palavras: ['cord', 'cords']
# 2
# O aglomerado possui as palavras: ['viruses', 'virus', 'malware', 'antivirus', 'strain', 'anti-virus', 'spyware', 'adware', 'firewall']
# 9
# O aglomerado possui as palavras: ['flip', 'flop']
# 2
# O aglomerado possui as palavras: ['fingerprint', 'fingerprints', 'handwriting']
# 3
# O aglomerado possui as palavras: ['surfing', 'surf']
# 2
# O aglomerado possui as palavras: ['angle', 'angles', 'vertical']
# 3
# O aglomerado possui as palavras: ['base', 'pinch', 'batter', 'outs', 'bases']
# 5
# O aglomerado possui as palavras: ['generation', 'legacy', 'generations']
# 3
# O aglomerado possui as palavras: ['downside', 'upside']
# 2
# O aglomerado possui as palavras: ['hrs', 'mins']
# 2
# O aglomerado possui as palavras: ['rating', 'rated', 'ratings']
# 3
# O aglomerado possui as palavras: ['gigs', 'gig']
# 2
# O aglomerado possui as palavras: ['screws', 'screw']
# 2
# O aglomerado possui as palavras: ['beast', 'monster', 'demon', 'dragon']
# 4
# O aglomerado possui as palavras: ['bugs', 'bug']
# 2
# O aglomerado possui as palavras: ['external', 'internal']
# 2
# O aglomerado possui as palavras: ['platform', 'platforms']
# 2
# O aglomerado possui as palavras: ['breaker', 'breakers']
# 2
# O aglomerado possui as palavras: ['par', 'hole', 'strokes', 'stroke']
# 4
# O aglomerado possui as palavras: ['muito', 'melhor']
# 2
# O aglomerado possui as palavras: ['dents', 'dings']
# 2
# O aglomerado possui as palavras: ['advice', 'tip', 'tips']
# 3
# O aglomerado possui as palavras: ['backup', 'backups']
# 2
# O aglomerado possui as palavras: ['dias', 'dos']
# 2
# O aglomerado possui as palavras: ['cooling', 'heating', 'vents', 'ventilation', 'vent']
# 5
# O aglomerado possui as palavras: ['lemon', 'cake', 'paste', 'coffee', 'juice', 'butter', 'nuts', 'candy', 'drink']
# 9
# O aglomerado possui as palavras: ['tap', 'taps']
# 2
# O aglomerado possui as palavras: ['unlock', 'unlocking']
# 2
# O aglomerado possui as palavras: ['code', 'codes']
# 2
# O aglomerado possui as palavras: ['entertainment', 'sports']
# 2
# O aglomerado possui as palavras: ['booting', 'booted']
# 2
# O aglomerado possui as palavras: ['spinning', 'spin']
# 2
# O aglomerado possui as palavras: ['pixels', 'pixel']
# 2
# O aglomerado possui as palavras: ['mark', 'marks']
# 2
# O aglomerado possui as palavras: ['zoom', 'zooming']
# 2
# O aglomerado possui as palavras: ['shutdown', 'shuts', 'shutdowns', 'shut']
# 4
# O aglomerado possui as palavras: ['recognition', 'status']
# 2
# O aglomerado possui as palavras: ['wall', 'street']
# 2
# O aglomerado possui as palavras: ['gold', 'silver', 'platinum']
# 3
# O aglomerado possui as palavras: ['sticker', 'stickers']
# 2
# O aglomerado possui as palavras: ['savvy', 'smart', 'knowledgeable']
# 3
# O aglomerado possui as palavras: ['couch', 'sofa', 'recliner']
# 3
# O aglomerado possui as palavras: ['temps', 'bons']
# 2
# O aglomerado possui as palavras: ['cd/dvd', 'dvd/cd']
# 2
# O aglomerado possui as palavras: ['beginners', 'beginner']
# 2
# O aglomerado possui as palavras: ['category', 'categories']
# 2
# O aglomerado possui as palavras: ['16gb', '32gb']
# 2
# O aglomerado possui as palavras: ['trick', 'tricks']
# 2
# O aglomerado possui as palavras: ['icons', 'icon', 'symbol', 'symbols']
# 4
# O aglomerado possui as palavras: ['shortcuts', 'shortcut']
# 2
# O aglomerado possui as palavras: ['indicator', 'indicators']
# 2
# O aglomerado possui as palavras: ['arrow', 'arrows']
# 2
# O aglomerado possui as palavras: ['leisure', 'park', 'recreation']
# 3
# O aglomerado possui as palavras: ['menu', 'recipes', 'menus']
# 3
# O aglomerado possui as palavras: ['geek', 'nerd']
# 2
# O aglomerado possui as palavras: ['palm', 'beach']
# 2
# O aglomerado possui as palavras: ['washed', 'wash']
# 2
# O aglomerado possui as palavras: ['8th', '1st', '2nd', '3rd', '6th', '7th', '5th', '4th', '29th', '9th']
# 10
# O aglomerado possui as palavras: ['clock', 'clocks']
# 2
# O aglomerado possui as palavras: ['quirks', 'nuances']
# 2
# O aglomerado possui as palavras: ['horsepower', 'rpm', 'turbo', 'engine']
# 4
# O aglomerado possui as palavras: ['compliments', 'compliment']
# 2
# O aglomerado possui as palavras: ['serial', 'killer']
# 2
# O aglomerado possui as palavras: ['fire', 'fires']
# 2
# O aglomerado possui as palavras: ['magnet', 'magnets']
# 2
# O aglomerado possui as palavras: ['font', 'fonts']
# 2
# O aglomerado possui as palavras: ['c.', 's.']
# 2
# O aglomerado possui as palavras: ['tutorials', 'tutorial']
# 2
# O aglomerado possui as palavras: ['movement', 'resistance', 'freedom', 'movements']
# 4
# O aglomerado possui as palavras: ['stream', 'streams', 'flow']
# 3
# O aglomerado possui as palavras: ['horse', 'dog', 'puppy', 'pet']
# 4
# O aglomerado possui as palavras: ['schooler', 'grader']
# 2
# O aglomerado possui as palavras: ['gripe', 'gripes']
# 2
# O aglomerado possui as palavras: ['bullet', 'caliber']
# 2
# O aglomerado possui as palavras: ['ergonomics', 'ergonomic']
# 2
# O aglomerado possui as palavras: ['keeper', 'defender']
# 2
# O aglomerado possui as palavras: ['gen', 'na']
# 2
# O aglomerado possui as palavras: ['smudges', 'stains']
# 2
# O aglomerado possui as palavras: ['literate', 'illiterate']
# 2
# O aglomerado possui as palavras: ['constant', 'continuous']
# 2
# O aglomerado possui as palavras: ['partition', 'partitions']
# 2
# O aglomerado possui as palavras: ['transfer', 'transfers']
# 2
# O aglomerado possui as palavras: ['anti-', 'anti', 'counter']
# 3
# O aglomerado possui as palavras: ['preference', 'preferences']
# 2
# O aglomerado possui as palavras: ['noticeable', 'visible', 'slight']
# 3
# O aglomerado possui as palavras: ['intensive', 'intense']
# 2
# O aglomerado possui as palavras: ['bubble', 'boom']
# 2
# O aglomerado possui as palavras: ['tactile', 'visual']
# 2
# O aglomerado possui as palavras: ['blacks', 'whites']
# 2
# O aglomerado possui as palavras: ['ssds', 'solid-state']
# 2
# O aglomerado possui as palavras: ['notification', 'notifications']
# 2
# O aglomerado possui as palavras: ['hibernation', 'hibernate']
# 2
# O aglomerado possui as palavras: ['techie', 'techies']
# 2
# O aglomerado possui as palavras: ['check', 'checks']
# 2
# O aglomerado possui as palavras: ['circles', 'circle']
# 2
# O aglomerado possui as palavras: ['reflection', 'reflections']
# 2
# O aglomerado possui as palavras: ['picky', 'finicky']
# 2
# O aglomerado possui as palavras: ['upgradeable', 'upgradable']
# 2
# O aglomerado possui as palavras: ['workload', 'workloads']
# 2
# O aglomerado possui as palavras: ['pre-installed', 'preinstalled']
# 2
# O aglomerado possui as palavras: ['cycles', 'cycle']
# 2
# O aglomerado possui as palavras: ['on-screen', 'onscreen']
# 2
# O aglomerado possui as palavras: ['patches', 'patch']
# 2
# O aglomerado possui as palavras: ['planet', 'universe']
# 2
# O aglomerado possui as palavras: ['attachment', 'attachments']
# 2
# O aglomerado possui as palavras: ['moments', 'awkward']
# 2
# O aglomerado possui as palavras: ['porch', 'patio']
# 2
# O aglomerado possui as palavras: ['full-size', 'full-sized']
# 2
# O aglomerado possui as palavras: ['coworkers', 'coworker']
# 2
# O aglomerado possui as palavras: ['accents', 'accent']
# 2

# %% [markdown]
# Ao fazer testes, vi que o DBSCAN fez alguns aglomerados interessantes, mas infelizmente juntou a grande maioria das palavras em um único aglomerado. Vou tentar com outro método, o aglomerativo.

# %%
from sklearn.cluster import AgglomerativeClustering
AgCl = AgglomerativeClustering(n_clusters=None, affinity="cosine", compute_full_tree=True, linkage="complete", distance_threshold=0.8)

AgCl.fit(vec)

tiposAg = AgCl.labels_[range(len(pal))]

print("Quantidade de aglomerados encontrados:" , len(np.unique(tiposAg)-1))
print("Quantidade de palavras sem aglomerado:" , np.count_nonzero(tiposAg == -1))
# Out:
# Quantidade de aglomerados encontrados: 704
# Quantidade de palavras sem aglomerado: 0

# %%
def conteudoDoClusterAg(numCluster):
    conteudos = []
    for i in range(len(pal)):
        if(tiposAg[i]==numCluster): 
            conteudos.append(pal[i])
    print("O aglomerado possui as palavras:",conteudos)
    print(len(conteudos))


def estaEmClusterAg(palavraPraChecar):
    for i in range(len(pal)):
        if(pal[i]==palavraPraChecar): 
            print("A palavra", pal[i], "está na posição", i, "da lista, e no cluster", tiposAg[i])
            if(tipos[i]!=-1): 
                conteudoDoClusterAg(tiposAg[i])
            else:
                print("A palavra foi considerada como outlier.")
            return
    print("Palavra não encontrada.")

# %%
estaEmClusterAg("port")
# Out:
# A palavra port está na posição 142 da lista, e no cluster 272
# O aglomerado possui as palavras: ['ports', 'port', 'shipping', 'dock', 'docks', 'freight']
# 6
